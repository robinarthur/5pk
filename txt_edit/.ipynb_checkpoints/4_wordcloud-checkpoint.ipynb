# %%
# this tutorial was taken from:
# https://www.datacamp.com/community/tutorials/wordcloud-python
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
#% matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
# load the data/ pickle
import pickle

# load it
with open('./data/output_df_wth_all_nr_all_perc_reading.pickle', 'rb') as handle:
    data = pickle.load(handle) 

df = data

# alles auf 2 Nachkommastellen beschränken
df.round(2)
# Out:
#                                           name style  \
# number
# 0001                                 Demetrius     D
# 0002               Der versöhnte Menschenfeind     D
# 0003                     Die Braut von Messina     D
# 0004                  Die Huldigung der Künste     D
# 0005                  Die Jungfrau von Orleans     D
# 0006                                Die Räuber     D
# 0007      Die Verschwörung des Fiesco zu Genua     D
# 0008                                Don Carlos     D
# 0009                          Kabale und Liebe     D
# 0010                              Maria Stuart     D
# 0011                                    Semele     D
# 0012                               Wallenstein     D
# 0013                              Wilhelm Tell     D
# 0014                                 Der Abend     G
# 0015                                    Amalia     G
# 0016                             an die Freude     G
# 0017                                 Euripides     N
# 0018                   das Ideal und das Leben     G
# 0019            das verschleierte Bild zu Sais     G
# 0020                              der Eroberer     G
# 0021                          der Geisterseher     E
# 0022                       der Neffe als Onkel     N
# 0023                               der Parasit     N
# 0024                           der Spaziergang     G
# 0025                            der Venuswagen     G
# 0026        der Verbrecher aus verlorener Ehre     E
# 0027                         die deutsche Muse     G
# 0028                   die Entzückung an Laura     G
# 0029    die Götter Griechenlands erste Fassung     G
# 0030                                die Ideale     G
# ...                                        ...   ...
# 0634                       an P Sachsen Weimar     B
# 0635                           an B Fischenich     B
# 0636                           an W C Reinwald     B
# 0637                               an H Weimar     B
# 0638                              an K Schwarz     B
# 0639                            an L Lengefeld     B
# 0640                                 an Genast     B
# 0641                             an W Wolzogen     B
# 0642                                an K Beyme     B
# 0643                                an F Cotta     B
# 0644                             an J Herzfeld     B
# 0645                             an C Hufeland     B
# 0646                               an W Goethe     B
# 0647                                 an H Voss     B
# 0648                              an G Koerner     B
# 0649                             an C Reinhart     B
# 0650                             an W Humboldt     B
# 0651                                an K Gross     B
# 0652                              an S Crusius     B
# 0653                             an F Rochlitz     B
# 0654                             an G Goeschen     B
# 0655                              an A Iffland     B
# 0656                             an F Frommann     B
# 0657                               an H Paulus     B
# 0658                           an F Niethammer     B
# 0659                               an L Frankh     B
# 0660                                an F Cotta     B
# 0661                                an F Stein     B
# 0662                               an W Goethe     B
# 0663                              an G Koerner     B
#
#                                                      text  year    year_dt  \
# number
# 0001    Demetrius an der russischen Grenze   Er ist vo...  1805 1805-01-01
# 0002    Der versöhnte Menschenfeind - Fragment  Gegend...  1790 1790-01-01
# 0003    Die Braut von Messina oder die feindlichen Brü...  1803 1803-01-01
# 0004    Ihrer Kaiserl. Hoheit       der Frau Erbprinze...  1804 1804-01-01
# 0005    Die Jungfrau von Orleans Eine romantische Trag...  1801 1801-01-01
# 0006    Die Räuber Ein Schauspiel        Quae medicame...  1781 1781-01-01
# 0007    Die Verschwörung des Fiesco zu Genua Ein repub...  1783 1783-01-01
# 0008     Don Carlos, Infant von Spanien Ein dramatisch...  1788 1788-01-01
# 0009     Kabale und Liebe Ein bürgerliches Trauerspiel...  1784 1784-01-01
# 0638                  70.73         9.1                   7.7
# 0639                  92.02         7.3                   3.7
# 0640                  78.35         8.5                   4.8
# 0641                  80.92         8.1                   5.9
# 0642                  52.63        13.3                  12.6
# 0643                  71.04         8.8                   7.6
# 0644                  71.95         9.2                   7.2
# 0645                  67.49         9.9                   9.0
# 0646                  82.14         8.5                   5.4
# 0647                  83.05         8.8                   5.1
# 0648                  81.93         8.2                   5.5
# 0649                  77.98         7.4                   7.0
# 0650                  71.58         9.3                   9.5
# 0651                  73.10        10.2                   8.9
# 0652                  76.52         8.1                   5.5
# 0653                  74.79         8.5                   6.2
# 0654                  88.97         8.0                   4.8
# 0655                  81.73         8.6                   5.6
# 0656                  74.49         7.5                   6.3
# 0657                  84.27         8.5                   4.6
# 0658                  73.47         8.1                   6.7
# 0659                  77.06         8.8                   7.4
# 0660                  71.85         8.9                   7.3
# 0661                  77.57         7.6                   7.2
# 0662                  69.72         9.5                   8.1
# 0663                  79.60         8.7                   6.4
#
#         coleman_liau_index  automated_readability_index  \
# number
# 0001                 12.93                         11.2
# 0002                 12.23                          9.9
# 0003                 12.46                         10.6
# 0004                 11.82                         10.1
# 0005                 11.59                          9.2
# 0006                 11.01                          8.6
# 0007                 12.44                          8.9
# 0008                 10.65                          7.6
# 0009                 10.88                          8.1
# 0010                 12.22                          9.5
# 0011                 13.61                         10.5
# 0012                 11.58                          8.8
# 0013                 11.30                          9.3
# 0014                 13.18                         19.4
# 0015                 13.98                         12.2
# 0016                 10.19                          7.1
# 0017                 12.46                         10.1
# 0018                 14.86                         15.8
# 0019                 12.17                          9.9
# 0020                 14.28                         18.2
# 0021                 13.34                         12.5
# 0022                 12.57                          9.3
# 0023                 13.03                          9.5
# 0024                 13.69                         13.3
# 0025                 14.44                         12.9
# 0026                 13.69                         12.3
# 0027                 14.68                         15.5
# 0028                 15.39                         21.4
# 0029                 14.85                         13.9
# 0030                 12.53                         13.8
# ...                    ...                          ...
# 0634                 12.98                         11.2
# 0635                 11.46                          8.3
# 0636                  9.34                          9.0
# 0637                 14.45                         13.7
# 0638                 14.67                         13.5
# 0639                  9.90                          7.9
# 0640                 12.10                          8.6
# 0641                 11.42                         10.0
# 0642                 18.28                         20.7
# 0643                 11.89                         11.0
# 0644                 14.15                         12.4
# 0645                 13.11                         13.6
# 0646                 12.06                         10.1
# 0647                 11.53                          9.3
# 0648                 11.71                         10.0
# 0649                 10.33                         10.3
# 0650                 12.77                         15.2
# 0651                 13.29                         14.9
# 0652                 14.54                         11.2
# 0653                 11.07                          8.8
# 0654                 11.25                         10.0
# 0655                 12.00                         10.3
# 0656                 12.35                         10.0
# 0657                 11.99                          9.3
# 0658                 12.58                         10.7
# 0659                 13.17                         13.1
# 0660                 12.06                         10.8
# 0661                 12.59                         12.3
# 0662                 13.40                         12.7
# 0663                 11.95                         11.0
#
#         dale_chall_readability_score  difficult_words  linsear_write_formula  \
# number
# 0001                            7.14           1450.0                   4.88
# 0002                            6.92           1193.0                   3.64
# 0003                            6.63           3508.0                   7.92
# 0004                            7.35            333.0                   6.43
# 0005                            6.31           3747.0                  53.50
# 0028          25.85   9th and 10th grade
# 0029          19.89    8th and 9th grade
# 0030          18.74    8th and 9th grade
# ...             ...                  ...
# 0634          18.61    5th and 6th grade
# 0635          14.65    7th and 8th grade
# 0636          17.03    6th and 7th grade
# 0637          18.02    7th and 8th grade
# 0638          18.39    7th and 8th grade
# 0639          12.34    7th and 8th grade
# 0640          17.27    8th and 9th grade
# 0641          15.04    6th and 7th grade
# 0642          24.06  12th and 13th grade
# 0643          14.51    7th and 8th grade
# 0644          18.52    8th and 9th grade
# 0645          19.70    8th and 9th grade
# 0646          14.66  12th and 13th grade
# 0647          15.11    8th and 9th grade
# 0648          14.76    8th and 9th grade
# 0649          16.70    6th and 7th grade
# 0650          19.98   9th and 10th grade
# 0651          19.76    8th and 9th grade
# 0652          16.60    7th and 8th grade
# 0653          15.96    8th and 9th grade
# 0654          15.86    7th and 8th grade
# 0655          16.01    5th and 6th grade
# 0656          17.44    7th and 8th grade
# 0657          15.35    8th and 9th grade
# 0658          16.76    7th and 8th grade
# 0659          18.58    8th and 9th grade
# 0660          15.12    6th and 7th grade
# 0661          18.25    7th and 8th grade
# 0662          16.62  12th and 13th grade
# 0663          16.53    8th and 9th grade
#
# [663 rows x 22 columns]

# %%
df.head()
# Out:
#                                name style  \
# number
# 0001                      Demetrius     D
# 0002    Der versöhnte Menschenfeind     D
# 0003          Die Braut von Messina     D
# 0004       Die Huldigung der Künste     D
# 0005       Die Jungfrau von Orleans     D
#
#                                                      text  year    year_dt  \
# number
# 0001    Demetrius an der russischen Grenze   Er ist vo...  1805 1805-01-01
# 0002    Der versöhnte Menschenfeind - Fragment  Gegend...  1790 1790-01-01
# 0003    Die Braut von Messina oder die feindlichen Brü...  1803 1803-01-01
# 0004    Ihrer Kaiserl. Hoheit       der Frau Erbprinze...  1804 1804-01-01
# 0005    Die Jungfrau von Orleans Eine romantische Trag...  1801 1801-01-01
#
#         nr_token  nr_adj  nr_noun  nr_verb   per_verb         ...           \
# number                                                        ...
# 0001      8486.0   600.0   1681.0   1482.0  17.464058         ...
# 0002      7127.0   584.0   1328.0   1286.0  18.044058         ...
# 0003     27129.0  2348.0   5122.0   3624.0  13.358399         ...
# 0004      1985.0   157.0    452.0    242.0  12.191436         ...
# 0005     32189.0  2308.0   6195.0   4801.0  14.915033         ...
#
#         flesch_reading_ease  smog_index  flesch_kincaid_grade  \
# number
# 0001                  72.46         8.9                   7.1
# 0002                  82.75         8.1                   5.2
# 0003                  14.15         8.2                  15.0
# 0004                  22.51         7.4                  13.8
# 0005                  16.08         7.6                  14.2
#
#         coleman_liau_index  automated_readability_index  \
# number
# 0001                 12.93                         11.2
# 0002                 12.23                          9.9
# 0003                 12.46                         10.6
# 0004                 11.82                         10.1
# 0005                 11.59                          9.2
#
#         dale_chall_readability_score  difficult_words  linsear_write_formula  \
# number
# 0001                            7.14           1450.0               4.875000
# 0002                            6.92           1193.0               3.636364
# 0003                            6.63           3508.0               7.916667
# 0004                            7.35            333.0               6.428571
# 0005                            6.31           3747.0              53.500000
#
#         gunning_fog        text_standard
# number
# 0001      15.169998    6th and 7th grade
# 0002      14.138439    3th and 4th grade
# 0003      13.646646    7th and 8th grade
# 0004      15.489678    6th and 7th grade
# 0005      12.311578  11th and 12th grade
#
# [5 rows x 22 columns]

# %%
# groupby by style
types = df.groupby('style')

# summary statistic of all types
types.describe()
# Out:
#       automated_readability_index                                            \
#                             count       mean       std   min     25%    50%
# style
# B                           478.0  12.369665  2.881732   6.3  10.625  12.00
# D                            15.0   9.700000  1.251285   7.6   8.850   9.50
# E                             8.0  15.787500  5.208904  11.1  12.025  14.55
# G                           130.0  12.826923  4.422507   4.0  10.225  12.25
# H                             4.0  20.900000  3.706751  16.8  19.425  20.50
# N                             8.0  10.125000  1.664546   8.7   9.000   9.40
# P                            20.0  19.975000  2.636560  15.1  18.200  19.85
#
#                     coleman_liau_index             ...    per_verb             \
#           75%   max              count       mean  ...         75%        max
# style                                              ...
# B      13.500  28.1              478.0  13.359184  ...   17.284953  22.972973
# D      10.550  12.2               15.0  12.108000  ...   17.315421  18.044058
# E      17.475  26.1                8.0  14.621250  ...   18.558950  18.752080
# G      14.375  33.6              130.0  12.557923  ...   14.575229  27.272727
# H      21.975  25.8                4.0  16.907500  ...   15.963110  16.728289
# N      10.625  13.2                8.0  12.565000  ...   14.977098  15.354146
# P      22.000  24.7               20.0  15.986000  ...   15.866689  16.729089
#
#       smog_index
#            count       mean       std   min     25%    50%     75%   max
# style
# B          478.0   8.947490  1.324841   5.0   8.200   8.80   9.400  20.1
# D           15.0   7.786667  0.679145   6.7   7.450   7.60   8.150   9.1
# E            8.0  10.387500  2.294987   8.1   8.725   9.95  11.100  15.0
# G          130.0   6.927692  2.873375   0.0   6.400   7.65   8.400  11.9
# H            4.0  12.450000  1.506652  10.9  11.725  12.20  12.925  14.5
# N            8.0   7.462500  0.682302   6.7   7.075   7.30   7.600   8.9
# P           20.0  12.295000  1.006021  10.3  11.800  12.45  12.950  14.1
#
# [7 rows x 128 columns]

# %%
types.mean().sort_values(by='nr_token', ascending=False).round(2)
# Out:
#        nr_token   nr_adj   nr_noun   nr_verb  per_verb  per_noun  per_adj  \
# style
# H      79901.50  7110.25  17452.75  11956.00     15.04     22.05     9.52
# D      25174.80  1761.93   4664.00   3924.33     15.54     19.23     7.18
# E      20901.12  1436.62   3852.88   3785.25     17.02     19.36     8.37
# N      14226.00   978.00   2598.25   2110.12     14.51     19.18     7.14
# P       8542.35   809.55   1770.55   1300.05     15.31     20.74     9.84
# B       1935.78   162.98    319.64    322.31     15.83     17.04     8.64
# G        414.99    37.56     95.09     51.16     12.54     21.96     8.58
#
#        flesch_reading_ease  smog_index  flesch_kincaid_grade  \
# style
# H                    55.78       12.45                 12.95
# D                    44.05        7.79                 10.38
# E                    66.41       10.39                  9.62
# N                    67.56        7.46                  7.12
# P                    56.31       12.29                 12.74
# B                    74.34        8.95                  7.19
# G                    19.55        6.93                 15.40
#
#        coleman_liau_index  automated_readability_index  \
# style
# H                   16.91                        20.90
# D                   12.11                         9.70
# E                   14.62                        15.79
# N                   12.56                        10.12
# P                   15.99                        19.97
# B                   13.36                        12.37
# G                   12.56                        12.83
#
#        dale_chall_readability_score  difficult_words  linsear_write_formula  \
# style
# H                              7.67          6923.25                  12.53
# D                              6.64          3045.13                  12.93
# E                              7.82          2485.50                  15.59
# N                              6.70          1882.12                   4.98
# P                              8.23          1438.65                  15.94
# B                              7.91           309.86                   7.98
# G                              7.81            76.70                   8.68
#
#        gunning_fog
# style
# H            20.46
# D            13.21
# E            18.83
# N            13.39
# P            21.73
# B            17.58
# G            17.96

# %%
plt.figure(figsize=(15,10))
types.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=0)
plt.xlabel("style")
plt.ylabel("Anzahl")
plt.show()

# %%
plt.figure(figsize=(15,10))
types.max().sort_values(by="nr_token", ascending=False)["nr_token"].plot.bar()
plt.xticks(rotation=50)
plt.xlabel("style")
plt.ylabel("nr_token")
plt.show()

# %%
# start with one text
text = df.text[0]

# create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=50, max_words=50, background_color='white').generate(text)

# display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Save the image in the img folder:
wordcloud.to_file("./data/img/first_review.png")

# %%
# now one wordcloud with all the text
text = ' '.join(text for text in df.text)
print('There are {} words in the combination of all texts.'.format(len(text)))

# how many unique words are in the dataset:
words = text.split(' ')
print('There are {} unique words in the combination of all texts.'.format(len(set(words))))
# Out:
# There are 13379801 words in the combination of all texts.
# There are 148291 unique words in the combination of all texts.

# %%
# import spacy for the german stopwordlist:
import spacy
nlp = spacy.load('de')
# import the spacy stopwords
from spacy.lang.de.stop_words import STOP_WORDS

# %%
# create a stopword list:
stopwords = set(STOP_WORDS)
stopwords.update(['bla', 'blabla', 'blablabla'])

#print(stopwords)

# generate a world cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color='white').generate(text)

# save the wordcloud
wordcloud.to_file("./data/img/wordcloud_complete_text.png")

# display the generated image
# the matplotlib way
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# now its time for a schiller shaped picture and wordcloud
schiller_mask = np.array(Image.open("./data/img/schiller_unterschrift.png"))

schiller_mask = schiller_mask.reshape((schiller_mask.shape[0],-1), order='F')

def transform_format(val):
    if val.any() == 0:
        return 255
    else:
        return val

# Transform your mask into a new one that will work with the function:
transformed_schiller_mask = np.ndarray((schiller_mask.shape[0],schiller_mask.shape[1]), np.int32)

for i in range(len(schiller_mask)):
    transformed_schiller_mask[i] = list(map(transform_format, schiller_mask[i]))

# Check the expected result of your mask
transformed_schiller_mask
# Out:
# array([[239, 239, 239, ..., 239, 239, 239],
#        [239, 239, 239, ..., 239, 239, 239],
#        [239, 239, 239, ..., 239, 239, 239],
#        ...,
#        [239, 239, 239, ..., 239, 239, 239],
#        [239, 239, 239, ..., 239, 239, 239],
#        [239, 239, 239, ..., 239, 239, 239]], dtype=int32)

# %%
# create a word cloud image
# colors could be found here:
# https://matplotlib.org/2.0.0/examples/color/named_colors.html
wc = WordCloud(background_color='white', max_words=1000, mask=transformed_schiller_mask,
              stopwords=stopwords, contour_width=1, contour_color='black')

# generate the wordcloud
wc.generate(text)

# save it in a file
wc.to_file('./data/img/schiller_wordcloud_sign.png')

# show it here:
plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
