# %% [markdown]
# This is a try and error notebook to rebuild the counting function for the numbers of verbs, subjects, words in general and so on...

# %%
# import von Pandas, Betriebssystemfunktionen als  Bibliotheken laden
import pandas as pd
import json
import os


# open the date

file_path = './data/'

# try to clean the raw data
# open the data json file and load it into the RAM
with open(file_path + 'data.json') as infile:
    # read the json structure
    d = json.load(infile)
    
    # d is a list of dict objects
    for book in d:
        # every book is a dict
        for key in book.keys():
            # replace the \n - new line character with a whitespace
            book[key] = book[key].replace('\n', ' ')
            # replace some worde with whitespace
            book[key] = book[key].replace('[Fußnote]', ' ')
            
        book['year_dt'] = pd.to_datetime(book['year'], infer_datetime_format=True)
    

# build a dataframe

# put all of the books into an pandas Dataframe
data = pd.DataFrame(d).set_index('number')


import spacy
from spacy.lang.de import German

nlp = spacy.load('de')

# %%
#data = data[:5]
data
# Out:
#                                                      name style  \
# number
# 0001                                            Demetrius     D
# 0002                          Der versöhnte Menschenfeind     D
# 0003                                Die Braut von Messina     D
# 0004                             Die Huldigung der Künste     L
# 0005                             Die Jungfrau von Orleans     D
# 0006                                           Die Räuber     D
# 0007                 Die Verschwörung des Fiesco zu Genua     D
# 0008                                           Don Carlos     D
# 0009                                     Kabale und Liebe     D
# 0010                                         Maria Stuart     D
# 0011                                               Semele     L
# 0012                                          Wallenstein     D
# 0013                                         Wilhelm Tell     D
# ...

# %%
# %time
from collections import defaultdict

def calculate_the_word_types(data):
    nouns = defaultdict(lambda: 0)
    verbs = defaultdict(lambda: 0)
    adjectives = defaultdict(lambda: 0)

    for i, row in data.iterrows():
        doc = nlp(row["name"] + " " + row["text"])
        data.set_value(i, "nr_token", len(list(map(lambda x: x.text, 
                                         filter(lambda x: x.pos_ != 'PUNCT', doc)))))
    
        for a in map(lambda x: x.lemma_, filter(lambda x: x.pos_ == 'ADJ', doc)):
            adjectives[a] += 1
        data.set_value(i, "nr_adj", len(list(map(lambda x: x.text, 
                                         filter(lambda x: x.pos_ == 'ADJ', doc)))))  
    
        for n in map(lambda x: x.lemma_, filter(lambda x: x.pos_ == 'NOUN', doc)):
            nouns[n] +=1
        data.set_value(i, "nr_noun", len(list(map(lambda x: x.text, 
                                         filter(lambda x: x.pos_ == 'NOUN', doc)))))

        for v in map(lambda x: x.lemma_, filter(lambda x: (x.pos_ == 'AUX') | (x.pos_ == 'VERB'), doc)):
            verbs[v] += 1
        data.set_value(i, "nr_verb", len(list(map(lambda x: x.text, 
                                         filter(lambda x: (x.pos_ == 'AUX') | (x.pos_ == 'VERB'), doc)))))  
    
    return data


###############################################
#
#
#          ACHTUNG DAS AUSFÜHREN DAUERT der 
#             kompletten Daten (~90 books)
#
#
#
#    KNAPP 5 MINUTEN - BITTE das PICKLE laden
#
#               !!!!!!!!!!!!!!!
#
##############################################


data = calculate_the_word_types(data)
# %time
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 8.34 µs
# /home/robinarthur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# /home/robinarthur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/robinarthur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/robinarthur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# CPU times: user 10 µs, sys: 3 µs, total: 13 µs
# Wall time: 650 µs

# %%
data
# Out:
#                                                      name style  \
# number
# 0001                                            Demetrius     D
# 0002                          Der versöhnte Menschenfeind     D
# 0003                                Die Braut von Messina     D
# 0004                             Die Huldigung der Künste     L
# 0005                             Die Jungfrau von Orleans     D
# 0006                                           Die Räuber     D
# 0007                 Die Verschwörung des Fiesco zu Genua     D
# 0008                                           Don Carlos     D
# 0009                                     Kabale und Liebe     D
# 0010                                         Maria Stuart     D
# 0011                                               Semele     L
# 0012                                          Wallenstein     D
# 0013                                         Wilhelm Tell     D
# ...

# %%
# Import all the necessary libraries

import os
import sys
import pandas as pd

from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

# %%
from dateutil.parser import parse

def is_date(string):
    try: 
        parse(string)
        return True
    except ValueError:
        return False
    
def get_letter_text(link):
    return str(link)

# %%
base_start = 'http://www.wissen-im-netz.info/literatur/schiller/briefe/1'
base_end = '/index.htm'

for i in range(793,794 ):#806
    url = base_start + str(i) + base_end
    
    print(url)
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    url = urlopen(req)
    content = url.read()
    soup = BeautifulSoup(content, 'lxml')

    
    table = soup.find('tbody')#, attrs={'class':'subs noBorders evenRows'})
    table_rows = table.find_all('tr')

    for tr in table_rows:
        td = tr.find_all('td')
        row = [tr.text for tr in td]
        #print(row)     
    
    l = []
    for tr in table_rows:
        td = tr.find_all('td')
        hr = td.find_all('a', href=True)
        print('hr', hr)
        if hr:
            link = hr.get('href')
            letter_url = base_start + str(i) + '/' + str(link)

            print(letter_url)
        row = [tr.text for tr in td]
        #print(row)
        #print('#####')
        hr = tag.find('a', href=True)
        if hr:
            link = hr.get('href')
            letter_url = base_start + str(i) + '/' + str(link)
            row[-1] = letter_url
            print(hr)
        
        l.append(row)
        
    df = pd.DataFrame(l, columns=["date", "receiver", "link"])
    df
    
"""
    n = 1
    #date, text, receiver set to nothing
    d, text, r, link = '','','', ''
    df = pd.DataFrame(columns=['date','receiver','text'])

    div = soup.findAll("td",{"valign" : "top"})
    for tag in div:
        l = tag.find('a', href=True)
        if l:
            link = l.get('href')
            letter_url = base_start + str(i) + '/' + str(link)
            #print(link)
            text = get_letter_text(letter_url)
        t = tag.get_text()
        
        if is_date(t):
            d = str(t)
            
        if t[0] == 'a' and t[1] == 'n':
            r = t
        
        letter = [d,r,text]
        #df2 = pd.DataFrame(letter, columns=['date','receiver','text'])
        print('letter', letter)
        r = df.join(letter)

        
        #print(df)
        #print('link',l)
        #print('text',t)
        #print('date',d)
        #print('receiver',r)
        #print('letter',letter)

        n += 1
        if n == 10:
            break  
        

    tempfile = 'temp.txt'
        
    with open(tempfile, 'w') as temp:
        temp.write(text)

    # open the textfile
    with open(tempfile, 'r') as f:
        text_lines = f.readlines()
        f.close()
    break
    # get the title of the poem
    title = text_lines[1]
    
    # folgendes ist notwendig, damit der new line character nicht im 
    # titel erscheint. 
    title = title[:-2]
    print(title)
    #write the poem into its own textfile
    with open('./input/txt/to_process/' + str(title) + '.txt', 'w') as pfile:
        pfile.write(text)
        

    ## Try to delete the temp file ##
    try:
        os.remove(tempfile)
    except OSError as e:  ## if failed, report it back to the user ##
        print ("Error: %s - %s." % (e.filename, e.strerror))
    
    data = []
        
    # get all the elements from the table
    table = soup.findAll("td",{"valign" : "top"})
    
    print(type(table))
    #table_body = table.find('tbody')
    
    for t in table:
        print(str(t))
        rows = t.find_all('tr')
        #print(rows.get_text)
        cols = t.find_all('td')
        #print(cols.get_text)
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele]) 
        
        
        
    print(data)
    
    for row in rows:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele]) # Get rid of empty values
    
    print(data)

    # get all the elements from the table
    div = soup.findAll("td",{"valign" : "top"})
    for tag in div:
        t = tag.get_text()
        
        if t == 'Datum' or t == 'Briefe von Schiller' or t == 'Briefe an Schiller':
            continue
        elif is_date(e):
            d = t
        
        table += t
  

    #
    while len(table) > 0:
        e = table.pop(0)
        if e == 'Datum' or e == 'Briefe von Schiller' or e == 'Briefe an Schiller':
            continue
        elif is_date(e):
            continue
        elif soup.find("td",attrs={"class":"fc_blabla"}).a["href"]

    print(table)
      

    tempfile = 'temp.txt'
        
    with open(tempfile, 'w') as temp:
        temp.write(text)

    # open the textfile
    with open(tempfile, 'r') as f:
        text_lines = f.readlines()
        f.close()
    
    # get the title of the poem
    title = text_lines[1]
    
    # folgendes ist notwendig, damit der new line character nicht im 
    # titel erscheint. 
    title = title[:-2]
    print(title)
    #write the poem into its own textfile
    with open('./input/txt/to_process/'+ str(i) + '/' + str(title) + '.txt', 'w') as pfile:
        pfile.write(text)
        

    ## Try to delete the temp file ##
    try:
        os.remove(tempfile)
    except OSError as e:  ## if failed, report it back to the user ##
        print ("Error: %s - %s." % (e.filename, e.strerror))
"""
# Out:
# http://www.wissen-im-netz.info/literatur/schiller/briefe/1793/index.htm
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-d8190c20a3dc> in <module>()
#      23     for tr in table_rows:
#      24         td = tr.find_all('td')
# ---> 25         hr = td.find_all('a', href=True)
#      26         print('hr', hr)
#      27         if hr:
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# ...

# %%
import requests, bs4, re, os
from urllib.parse import urljoin

base_start = 'http://www.wissen-im-netz.info/literatur/schiller/briefe/1'
base_end = 'index.htm'


def make_soup(url):
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    url = urlopen(req)
    content = url.read()
    soup = BeautifulSoup(content, 'lxml')
    return soup


def get_tds(link):
    soup = make_soup(link)
    table = soup.find('tbody')
    table_rows = table.find_all('tr')
    
    tds = [tr.find_all('td') for tr in table_rows]

    return tds
            
    
def get_links(txt):
    re1='.*?'	# Non-greedy match on filler
    re2='()'	# Tag 1
    re3='.*?'	# Non-greedy match on filler
    re4='<[^>]+>'	# Uninteresting: tag
    re5='.*?'	# Non-greedy match on filler
    re6='<[^>]+>'	# Uninteresting: tag
    re7='.*?'	# Non-greedy match on filler
    re8='(<[^>]+>)'	# Tag 2
    
    rg = re.compile(re1+re2+re3+re4+re5+re6+re7+re8,re.IGNORECASE|re.DOTALL)
    m = rg.search(txt)
    
    if m:
        tag1=m.group(1)
        tag2=m.group(2)
        return [tag1,tag2]   

def get_date(txt):
    re1='.*?'	# Non-greedy match on filler
    re2='((?:(?:[0-2]?\\d{1})|(?:[3][01]{1}))[-:\\/.](?:[0]?[1-9]|[1][012])[-:\\/.](?:(?:[1]{1}\\d{1}\\d{1}\\d{1})|(?:[2]{1}\\d{3})))(?![\\d])'	# DDMMYYYY 1
    
    rg = re.compile(re1+re2,re.IGNORECASE|re.DOTALL)
    m = rg.search(txt)
    
    if m:
        return m.group(1) 
    


def create_folder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' + directory)

   



if __name__ == '__main__':
    
    for i in range(793,794 ):#806
        next_url = base_start + str(i) + '/'
        complete_url = next_url + base_end
        
        tds = get_tds(complete_url)
        
        for element in tds:
            date = get_date(element)
            links = get_links(element)
            name = str(links)
            
            
            
        
        #links = get_links(complete_url)
        #for link in links:
        #    get_tds(link)
# Out:
# [<td align="left" valign="top"><strong>Datum</strong></td>, <td align="left" valign="top"><strong>Briefe von Schiller</strong></td>, <td align="left" valign="top"><strong>Briefe an Schiller</strong></td>]
# ########
# [<td align="right" valign="top">11.1.1793</td>, <td valign="top"><a href="17930111-an-G-Goeschen.htm" target="_top">an Georg Göschen</a><br/>
# <a href="17930111-an-G-Koerner.htm" target="_top">an Gottfried Körner</a></td>, <td valign="top"> </td>]
# ########
# [<td align="right" valign="top">14.1.1793</td>, <td valign="top"> </td>, <td valign="top">von Wilhelm v. Humboldt</td>]
# ########
# [<td align="right" valign="top">18.1.1793</td>, <td valign="top"> </td>, <td valign="top">von Gottfried Körner</td>]
# ########
# [<td align="right" valign="top">25.1.1793</td>, <td valign="top"><a href="17930125-an-G-Koerner.htm" target="_top">an Gottfried Körner</a></td>, <td valign="top"> </td>]
# ########
# ...
