# %%
# Beispiel aus dem IX Artikel

import sys
import pandas as pd
import sklearn
import spacy
import gensim
 
# !{sys.executable} -m spacy download de
nlp = spacy.load('de')
doc = nlp("Die Beispiele in diesem Tutorial sind daher in Python geschrieben und greifen auf \
eine Reihe von Python-Modulen zur Datenauswertung und -visualisierung zurück.")
spacy.displacy.render(doc, style='dep', jupyter=True)
# Out:
# ...
#     100% |████████████████████████████████| 38.2MB 8.1MB/s ta 0:00:011 1% |▌                               | 573kB 589kB/s eta 0:01:04    22% |███████▏                        | 8.6MB 2.7MB/s eta 0:00:12    28% |█████████▏                      | 11.0MB 2.4MB/s eta 0:00:12    29% |█████████▋                      | 11.4MB 10.7MB/s eta 0:00:03    34% |███████████                     | 13.0MB 3.2MB/s eta 0:00:08    58% |██████████████████▊             | 22.4MB 3.2MB/s eta 0:00:05    61% |███████████████████▉            | 23.7MB 12.1MB/s eta 0:00:02    66% |█████████████████████▎          | 25.4MB 4.8MB/s eta 0:00:03    86% |███████████████████████████▋    | 33.0MB 12.8MB/s eta 0:00:01    92% |█████████████████████████████▊  | 35.5MB 19.1MB/s eta 0:00:01    95% |██████████████████████████████▍ | 36.4MB 5.5MB/s eta 0:00:01    97% |███████████████████████████████▏| 37.2MB 12.7MB/s eta 0:00:01    99% |███████████████████████████████▉| 38.1MB 8.8MB/s eta 0:00:01
# ...
#
#     Linking successful
# ...
