# %%
# Beispiel aus dem IX Artikel

import sys
import pandas as pd
import sklearn
import spacy
import gensim
 
# !{sys.executable} -m spacy download de
nlp = spacy.load('de')
doc = nlp("Krafti nein, ich mache hier jetzt selber.")
spacy.displacy.render(doc, style='dep', jupyter=True)
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-2.0.0/de_core_news_sm-2.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-2.0.0/de_core_news_sm-2.0.0.tar.gz (38.2MB)
#     100% |████████████████████████████████| 38.2MB 2.1MB/s ta 0:00:011  18% |█████▉                          | 7.0MB 1.0MB/s eta 0:00:30    27% |████████▊                       | 10.4MB 1.9MB/s eta 0:00:15    36% |███████████▋                    | 13.8MB 4.3MB/s eta 0:00:06    38% |████████████▏                   | 14.6MB 2.4MB/s eta 0:00:11    46% |███████████████                 | 17.8MB 6.0MB/s eta 0:00:04    74% |███████████████████████▊        | 28.3MB 4.0MB/s eta 0:00:03    74% |███████████████████████▉        | 28.5MB 3.7MB/s eta 0:00:03    76% |████████████████████████▌       | 29.2MB 3.3MB/s eta 0:00:03    86% |███████████████████████████▉    | 33.2MB 2.7MB/s eta 0:00:02    93% |██████████████████████████████  | 35.7MB 2.4MB/s eta 0:00:02
# Requirement already satisfied (use --upgrade to upgrade): de-core-news-sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-2.0.0/de_core_news_sm-2.0.0.tar.gz in /home/robinarthur/anaconda3/lib/python3.6/site-packages
# You are using pip version 18.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
#     Linking successful
#     /home/robinarthur/anaconda3/lib/python3.6/site-packages/de_core_news_sm
#     -->
#     /home/robinarthur/anaconda3/lib/python3.6/site-packages/spacy/data/de
#
#     You can now load the model via spacy.load('de')
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1275" height="399.5" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Krafti</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">nein,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">ich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">mache</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">hier</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">jetzt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">selber.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">sb</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">mo</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,266.5 L223.0,254.5 207.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">sb</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">mo</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">mo</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M595,264.5 C595,2.0 1100.0,2.0 1100.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">mo</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,266.5 L1108.0,254.5 1092.0,254.5" fill="currentColor"/>
# </g>
# </svg>

# %% [markdown]
# <h1> einlesen der Daten <h1>

# %%
# import von Pandas, Betriebssystemfunktionen als  Bibliotheken laden
import pandas as pd
import json
import os

# %% [markdown]
# <h2>Es folgen die Angaben der Speicherorte.<h2>

# %%
file_path = './data/'

# try to clean the raw data
# open the data json file and load it into the RAM
with open(file_path + 'data.json') as infile:
    # read the json structure
    d = json.load(infile)
    
    # d is a list of dict objects
    for book in d:
        # every book is a dict
        for key in book.keys():
            # replace the \n - new line character with a whitespace
            book[key] = book[key].replace('\n', ' ')
            # replace some worde with whitespace
            book[key] = book[key].replace('[Fußnote]', ' ')
            
        book['year_dt'] = pd.to_datetime(book['year'], infer_datetime_format=True)

# %% [markdown]
# <h2> Daten in ein speichereffizientes Format bringen <h2>

# %%
# put all of the books into an pandas Dataframe
data = pd.DataFrame(d).set_index('number')

# %% [markdown]
# <h2>Mit dem folgenden Befehlen verschaffen wir uns einen Überblick über die eingeladenen Daten.<h2>

# %%
data
# Out:
#                                                      name style  \
# number
# 0001                                            Demetrius     D
# 0002                          Der versöhnte Menschenfeind     D
# 0003                                Die Braut von Messina     D
# 0004                             Die Huldigung der Künste     L
# 0005                             Die Jungfrau von Orleans     D
# 0006                                           Die Räuber     D
# 0007                 Die Verschwörung des Fiesco zu Genua     D
# 0008                                           Don Carlos     D
# 0009                                     Kabale und Liebe     D
# 0010                                         Maria Stuart     D
# 0011                                               Semele     L
# 0012                                          Wallenstein     D
# 0013                                         Wilhelm Tell     D
# 0014                                            Der Abend     L
# 0015                                               Amalia     L
# 0016                                        an die Freude     L
# 0017                        das Geheimnis der Reminiszemz     L
# 0018                              das Ideal und das Leben     L
# 0019                       das verschleierte Bild zu Sais     L
# 0020                                         der Eroberer     L
# 0021                                     der Geisterseher     E
# 0022                                  der Neffe als Onkel     U
# 0023                                          der Parasit     U
# 0024                                      der Spaziergang
# 0025                                       der Venuswagen
# 0026                   der Verbrecher aus verlorener Ehre     E
# 0027                                    die deutsche Muse     L
# 0028                              die Entzückung an Laura     L
# 0029                die Götter Griechenlands ersteFassung     L
# 0030                                           die Ideale
# ...                                                   ...   ...
# 0064                                     Breite und Tiefe     L
# 0065                                             Columbus     L
# 0066                                  Das Eleusische Fest     L
# 0067              die Götter Griechenlands zweite Fassung     L
# 0068                                         das Geschenk     L
# 0069                                            das Glück     L
# 0070                                      der Alpenjaeger     L
# 0071                           Das Mädchen aus der Fremde     L
# 0072                              Das Mädchen von Orleans     L
# 0073                                       Das Siegesfest     L
# 0074                                 Das Spiel des Lebens     L
# 0075                                  Das weibliche Ideal     L
# 0076                                        Die Begegnung     L
# 0077                                   Des Mädchens Klage     L
# 0078                                     Zeus zu Herkules     L
# 0079                                Der Graf von Habsburg     L
# 0080                                Der Jüngling am Bache     L
# 0081                                      An den Frühling     L
# 0082                     An den Herausgeber der Propyläen     E
# 0083                                  an einen Moralisten     E
# 0084                                             An Minna
# 0085                           Das Glück und die Weisheit
# 0086    Denkwuerdigkeiten aus dem Leben des Marschalls...
# 0087                                       Der Flüchtling
# 0088                                            Der Kampf
# 0089                     der Spaziergang unter den Linden
# 0090                                der Triumph der Liebe
# 0091                                           die Blumen
# 0092                                     die Freundschaft
# 0093              Die Gesetzgebung des Lykurgus und Solon
#
#                                                      text  year    year_dt
# number
# 0001    Demetrius an der russischen Grenze   Er ist vo...  1805 1805-01-01
# 0002    Der versöhnte Menschenfeind - Fragment  Gegend...  1790 1790-01-01
# 0003    Die Braut von Messina oder die feindlichen Brü...  1803 1803-01-01
# 0004    Ihrer Kaiserl. Hoheit       der Frau Erbprinze...  1804 1804-01-01
# 0005    Die Jungfrau von Orleans Eine romantische Trag...  1801 1801-01-01
# 0006    Die Räuber Ein Schauspiel        Quae medicame...  1781 1781-01-01
# 0007    Die Verschwörung des Fiesco zu Genua Ein repub...  1783 1783-01-01
# 0008     Don Carlos, Infant von Spanien Ein dramatisch...  1788 1788-01-01
# 0009     Kabale und Liebe Ein bürgerliches Trauerspiel...  1784 1784-01-01
# 0010    Maria Stuart Trauerspiel in fünf Aufzügen  Eli...  1800 1800-01-01
# 0086    In den Geschichtbüchern, welche die merkwürdig...              NaT
# 0087    Frisch athmet des Morgens lebendiger Hauch;   ...              NaT
# 0088    Nein, länger werd' ich diesen Kampf nicht kämp...              NaT
# 0089    Wollmar und Edwin waren Freunde und wohnten in...              NaT
# 0090          Selig durch die Liebe       Götter – dur...              NaT
# 0091     Die Blumen.  Kinder der verjüngten Sonne,    ...              NaT
# 0092    Freund! genügsam ist der Wesenlenker – Schämen...              NaT
# 0093    Lykurgus.  Um den Lykurgischen Plan gehörig wü...              NaT
#
# [93 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 0001 to 0093
# Data columns (total 5 columns):
# name       93 non-null object
# style      93 non-null object
# text       93 non-null object
# year       93 non-null object
# year_dt    50 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 4.4+ KB

# %%
data.describe()
# Out:
#               name style                                               text  \
# count           93    93                                                 93
# unique          93     7                                                 93
# top     die Ideale     L  Die Braut von Messina oder die feindlichen Brü...
# freq             1    53                                                  1
# first          NaN   NaN                                                NaN
# last           NaN   NaN                                                NaN
#
#        year              year_dt
# count    93                   50
# unique   24                   23
# top          1797-01-01 00:00:00
# freq     43                   10
# first   NaN  1776-01-01 00:00:00
# last    NaN  1805-01-01 00:00:00

# %% [markdown]
# <h1>NLP<h1>
#
# <h2>Vorbereitung<h2>

# %% [markdown]
# Nun benötigen wir die spaCY-Bibliothek und da Modell für die deutsche Sprache.
#
# Mehr zu spaCY: https://spacy.io

# %%
import spacy
from spacy.lang.de import German

nlp = spacy.load('de')

# %% [markdown]
# Das durch spaCY erzeugte NLP-Objekt ist sehr groß und benötigt viel Speicher. Um das etwas zu entschärfen,
# werden nur die benötigen Daten, also Anzahl der Token, Adjektive, Substantive und Verben gespeichert.
# Dabei hilft defaultdict, weil hier alle Werte auf 0 gesetzt sind, das spart viele Fallunterscheidungen.
#
# Die Worte selbst werden auch in ihrer lemmatisierten Form (also grammatikalisch auf die Grundform reduziert)
# benötigt, um später Analysen damit durchführen zu können.

# %%
# %time
from collections import defaultdict

def calculate_the_word_types(data):
    nouns = defaultdict(lambda: 0)
    verbs = defaultdict(lambda: 0)
    adjectives = defaultdict(lambda: 0)

    for i, row in data.iterrows():
        doc = nlp(row["name"] + " " + row["text"])
        data.set_value(i, "nr_token", len(list(map(lambda x: x.text, 
                                         filter(lambda x: x.pos_ != 'PUNCT', doc)))))
    
        for a in map(lambda x: x.lemma_, filter(lambda x: x.pos_ == 'ADJ', doc)):
            adjectives[a] += 1
        data.set_value(i, "nr_adj", len(list(map(lambda x: x.text, 
                                         filter(lambda x: x.pos_ == 'ADJ', doc)))))  
    
        for n in map(lambda x: x.lemma_, filter(lambda x: x.pos_ == 'NOUN', doc)):
            nouns[n] +=1
        data.set_value(i, "nr_noun", len(list(map(lambda x: x.text, 
                                         filter(lambda x: x.pos_ == 'NOUN', doc)))))

        for v in map(lambda x: x.lemma_, filter(lambda x: (x.pos_ == 'AUX') | (x.pos_ == 'VERB'), doc)):
            verbs[v] += 1
        data.set_value(i, "nr_verb", len(list(map(lambda x: x.text, 
                                         filter(lambda x: (x.pos_ == 'AUX') | (x.pos_ == 'VERB'), doc)))))  
    
    return data


###############################################
#
#
#          ACHTUNG DAS AUSFÜHREN DAUERT
#
#
#
#    KNAPP 5 MINUTEN - BITTE das PICKLE laden
#
#               !!!!!!!!!!!!!!!
#
##############################################


data = calculate_the_word_types(data)
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 8.82 µs
# /home/robinarthur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# /home/robinarthur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/robinarthur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/robinarthur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %% [markdown]
# calculate the percentages of wordtypes in the text

# %%
def calculate_percentages_of_word_types(data):

    data['verb'] = data['nr_verb']/(data['nr_token']/100)
    data['noun'] = data['nr_noun']/(data['nr_token']/100)
    data['adj'] = data['nr_adj']/(data['nr_token']/100)   
        
        
    return data



data = calculate_percentages_of_word_types(data)

# %%
data
# Out:
#                                                      name style  \
# number
# 0001                                            Demetrius     D
# 0002                          Der versöhnte Menschenfeind     D
# 0003                                Die Braut von Messina     D
# 0004                             Die Huldigung der Künste     L
# 0005                             Die Jungfrau von Orleans     D
# 0006                                           Die Räuber     D
# 0007                 Die Verschwörung des Fiesco zu Genua     D
# 0008                                           Don Carlos     D
# 0009                                     Kabale und Liebe     D
# 0010                                         Maria Stuart     D
# 0011                                               Semele     L
# 0012                                          Wallenstein     D
# 0013                                         Wilhelm Tell     D
# 0014                                            Der Abend     L
# 0015                                               Amalia     L
# 0016                                        an die Freude     L
# 0017                        das Geheimnis der Reminiszemz     L
# 0018                              das Ideal und das Leben     L
# 0019                       das verschleierte Bild zu Sais     L
# 0020                                         der Eroberer     L
# 0021                                     der Geisterseher     E
# 0022                                  der Neffe als Onkel     U
# 0023                                          der Parasit     U
# 0024                                      der Spaziergang
# 0025                                       der Venuswagen
# 0026                   der Verbrecher aus verlorener Ehre     E
# 0027                                    die deutsche Muse     L
# 0028                              die Entzückung an Laura     L
# 0029                die Götter Griechenlands ersteFassung     L
# 0030                                           die Ideale
# ...                                                   ...   ...
# 0064                                     Breite und Tiefe     L
# 0065                                             Columbus     L
# 0066                                  Das Eleusische Fest     L
# 0067              die Götter Griechenlands zweite Fassung     L
# 0068                                         das Geschenk     L
# 0069                                            das Glück     L
# 0070                                      der Alpenjaeger     L
# 0071                           Das Mädchen aus der Fremde     L
# 0072                              Das Mädchen von Orleans     L
# 0073                                       Das Siegesfest     L
# 0074                                 Das Spiel des Lebens     L
# 0075                                  Das weibliche Ideal     L
# 0076                                        Die Begegnung     L
# 0077                                   Des Mädchens Klage     L
# 0078                                     Zeus zu Herkules     L
# 0079                                Der Graf von Habsburg     L
# 0080                                Der Jüngling am Bache     L
# 0081                                      An den Frühling     L
# 0082                     An den Herausgeber der Propyläen     E
# 0083                                  an einen Moralisten     E
# 0084                                             An Minna
# 0085                           Das Glück und die Weisheit
# 0086    Denkwuerdigkeiten aus dem Leben des Marschalls...
# 0087                                       Der Flüchtling
# 0088                                            Der Kampf
# 0089                     der Spaziergang unter den Linden
# 0090                                der Triumph der Liebe
# 0091                                           die Blumen
# 0092                                     die Freundschaft
# 0093              Die Gesetzgebung des Lykurgus und Solon
#
#                                                      text  year    year_dt  \
# number
ickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)

# load it
with open('./data/output_df_wth_nr_token_verb_noun_adj.pickle', 'rb') as handle:
    data = pickle.load(handle)

# %%
data
# Out:
#                                                      name style  \
# number
# 0001                                            Demetrius     D
# 0002                          Der versöhnte Menschenfeind     D
# 0003                                Die Braut von Messina     D
# 0004                             Die Huldigung der Künste     L
# 0005                             Die Jungfrau von Orleans     D
# 0006                                           Die Räuber     D
# 0007                 Die Verschwörung des Fiesco zu Genua     D
# 0008                                           Don Carlos     D
# 0009                                     Kabale und Liebe     D
# 0010                                         Maria Stuart     D
# 0011                                               Semele     L
# 0012                                          Wallenstein     D
# 0013                                         Wilhelm Tell     D
# 0014                                            Der Abend     L
# 0015                                               Amalia     L
# 0016                                        an die Freude     L
# 0017                        das Geheimnis der Reminiszemz     L
# 0018                              das Ideal und das Leben     L
# 0019                       das verschleierte Bild zu Sais     L
# 0020                                         der Eroberer     L
# 0021                                     der Geisterseher     E
# 0022                                  der Neffe als Onkel     U
# 0023                                          der Parasit     U
# 0024                                      der Spaziergang
# 0025                                       der Venuswagen
# 0026                   der Verbrecher aus verlorener Ehre     E
# 0027                                    die deutsche Muse     L
# 0028                              die Entzückung an Laura     L
# 0029                die Götter Griechenlands ersteFassung     L
# 0030                                           die Ideale
# ...                                                   ...   ...
# 0064                                     Breite und Tiefe     L
# 0065                                             Columbus     L
# 0066                                  Das Eleusische Fest     L
# 0067              die Götter Griechenlands zweite Fassung     L
# 0068                                         das Geschenk     L
# 0069                                            das Glück     L
# 0070                                      der Alpenjaeger     L
# 0071                           Das Mädchen aus der Fremde     L
# 0072                              Das Mädchen von Orleans     L
# 0073                                       Das Siegesfest     L
# 0074                                 Das Spiel des Lebens     L
# 0075                                  Das weibliche Ideal     L
# 0076                                        Die Begegnung     L
# 0077                                   Des Mädchens Klage     L
# 0078                                     Zeus zu Herkules     L
# 0079                                Der Graf von Habsburg     L
# 0080                                Der Jüngling am Bache     L
# 0081                                      An den Frühling     L
# 0082                     An den Herausgeber der Propyläen     E
# 0083                                  an einen Moralisten     E
# 0084                                             An Minna
# 0085                           Das Glück und die Weisheit
# 0086    Denkwuerdigkeiten aus dem Leben des Marschalls...
# 0087                                       Der Flüchtling
# 0088                                            Der Kampf
# 0089                     der Spaziergang unter den Linden
# 0090                                der Triumph der Liebe
# 0091                                           die Blumen
# 0092                                     die Freundschaft
# 0093              Die Gesetzgebung des Lykurgus und Solon
#
#                                                      text  year    year_dt  \
# number
# 0001    Demetrius an der russischen Grenze   Er ist vo...  1805 1805-01-01
# 0002    Der versöhnte Menschenfeind - Fragment  Gegend...  1790 1790-01-01
# 0003    Die Braut von Messina oder die feindlichen Brü...  1803 1803-01-01
# 0004    Ihrer Kaiserl. Hoheit       der Frau Erbprinze...  1804 1804-01-01
# 0005    Die Jungfrau von Orleans Eine romantische Trag...  1801 1801-01-01
# 0006    Die Räuber Ein Schauspiel        Quae medicame...  1781 1781-01-01
# 0007    Die Verschwörung des Fiesco zu Genua Ein repub...  1783 1783-01-01
# 0008     Don Carlos, Infant von Spanien Ein dramatisch...  1788 1788-01-01
# 0084       222.0    16.0     55.0     33.0
# 0085       108.0     5.0     21.0     15.0
# 0086     29543.0  1508.0   5376.0   5369.0
# 0087       233.0    24.0     64.0     26.0
# 0088       174.0    17.0     32.0     33.0
# 0089      1647.0   162.0    340.0    265.0
# 0090       818.0    49.0    273.0     55.0
# 0091       158.0    15.0     49.0     15.0
# 0092       361.0    38.0     99.0     32.0
# 0093     11089.0  1003.0   2373.0   1855.0
#
# [93 rows x 9 columns]

# %% [markdown]
# <h1>Auswertung</h1>

# %% [markdown]
# <h2> Wieviel Werke sind pro Jahr in der Datenbank</h2>

# %%
# Matplotlib for additional customization
from matplotlib import pyplot as plt
#%matplotlib inline

# Seaborn for plotting and styling
import seaborn as sns
from pandas.plotting import register_matplotlib_converters as rmc
rmc()

# %%
# create a schiller style color palette
schiller_type_colors = ['#78C850',  # Grass
                        #'#F08030',  # Fire
                        #'#6890F0',  # Water
                        #'#A8B820',  # Bug
                        #'#A8A878',  # Normal
                        #'#A040A0',  # Poison
                        '#F8D030',  # Electric
                        #'#E0C068',  # Ground
                        #'#EE99AC',  # Fairy
                        '#C03028',  # Fighting
                        #'#F85888',  # Psychic
                        #'#B8A038',  # Rock
                        #'#705898',  # Ghost
                        #'#98D8D8',  # Ice
                        '#7038F8',  # Dragon
                       ]

# %%
df = data.sort_values(["year"], ascending=True)[["name", "nr_verb", "year", "style"]]

# Plot using Seaborn
sns.lmplot(x='year', y='nr_verb', data=df,
          fit_reg=False,
          hue='style')

# Tweak using Matplotlib
plt.ylim(0, None)
plt.xlim(0, None)
plt.xticks(rotation=90)

plt.axvline(7, color="k", linestyle="--");





"""
x_pos = [x for x in range(1776, 1806)]
print(x_pos)
# swarm plot with schiller color palette
sns.swarmplot(x='year', y='nr_token', data=df,
             palette=schiller_type_colors)
plt.xticks(rotation=90)
# Thus we have to give more margin:
plt.subplots_adjust(bottom=0.4)

plt.axvline(8, color='r', linestyle='--', lw=2)
plt.plot()
"""
# Out:
# "\nx_pos = [x for x in range(1776, 1806)]\nprint(x_pos)\n# swarm plot with schiller color palette\nsns.swarmplot(x='year', y='nr_token', data=df,\n             palette=schiller_type_colors)\nplt.xticks(rotation=90)\n# Thus we have to give more margin:\nplt.subplots_adjust(bottom=0.4)\n\nplt.axvline(8, color='r', linestyle='--', lw=2)\nplt.plot()\n"

# %%
df
# Out:
#                                            name  nr_verb  year style
# number
# 0093    Die Gesetzgebung des Lykurgus und Solon   1855.0
# 0028                    die Entzückung an Laura     20.0           L
# 0072                    Das Mädchen von Orleans     21.0           L
# 0030                                 die Ideale     63.0
# 0032                         die Kindsmoerderin     70.0           L
# 0033                       die Teilung der Erde     46.0
# 0034                  eine grossmutige Handlung    179.0           E
# 0035                      eine Leichenphantasie     49.0
# 0036                           Hektors Abschied     22.0           L
# 0071                 Das Mädchen aus der Fremde     18.0           L
# 0069                                  das Glück     89.0           L
# 0068                               das Geschenk      4.0           L
# 0066                        Das Eleusische Fest    103.0           L
# 0065                                   Columbus     11.0           L
# 0064                           Breite und Tiefe     22.0           L
# 0062                Archimedes und der Schueler     14.0           L
# 0061                                  an Goethe     94.0           L
# 0060                   an einen Weltverbesserer     14.0           L
# 0059                    an die Proselytenmacher      6.0           L
# 0092                           die Freundschaft     32.0
# 0048                         Phantasie an Laura     45.0           L
# 0050                           Zenith und Nadir      5.0
# 0027                          die deutsche Muse     12.0           L
# 0053                           Laura am Klavier     21.0           L
# 0074                       Das Spiel des Lebens     23.0           L
# 0024                            der Spaziergang    207.0
# 0091                                 die Blumen     15.0
# 0090                      der Triumph der Liebe     55.0
# 0089           der Spaziergang unter den Linden    265.0
# 0088                                  Der Kampf     33.0
# ...                                         ...      ...   ...   ...
# 0019             das verschleierte Bild zu Sais     95.0  1795     L
# 0049                            Klage der Ceres     87.0  1796     L
# 0051      Über epische und dramatische Dichtung    134.0  1797     P
# 0037                                    an Emma     14.0  1797     L
# 0038                              das Geheimnis     28.0  1797     L
# 0039                    das Lied von der Glocke    301.0  1797     L
# 0040              der Gang nach dem Eisenhammer    213.0  1797     L
# 0041                              der Handschuh     35.0  1797     L
# 0042                    der Ring des Polykrates     96.0  1797     L
# 0043                                der Taucher    177.0  1797     L
# 0044                    die Kraniche des Ibykus    152.0  1797     L
# 0046                          Ritter Toggenburg     47.0  1797     L
# 0076                              Die Begegnung     42.0  1798     L
# 0077                         Des Mädchens Klage     23.0  1798     L
# 0012                                Wallenstein  10658.0  1799     D
# 0082           An den Herausgeber der Propyläen    598.0  1799     E
# 0067    die Götter Griechenlands zweite Fassung     75.0  1800     L
# 0010                               Maria Stuart   5173.0  1800     D
# 0005                   Die Jungfrau von Orleans   4801.0  1801     D
# 0054                                   Turandot   3605.0  1801     D
# 0073                             Das Siegesfest     99.0  1802     L
# 0058                             an die Freunde     49.0  1802     L
# 0080                      Der Jüngling am Bache     22.0  1803     L
# 0079                      Der Graf von Habsburg    119.0  1803     L
# 0003                      Die Braut von Messina   3624.0  1803     D
# 0070                            der Alpenjaeger     32.0  1804     L
# 0063                                   Berglied     34.0  1804     L
# 0004                   Die Huldigung der Künste    242.0  1804     L
# 0013                               Wilhelm Tell   4597.0  1804     D
# 0001                                  Demetrius   1482.0  1805     D
#
# [93 rows x 4 columns]

# %%
# Bar plot
# Count Plot (a.k.a. Bar Plot)
sns.countplot(x='year', data=df, palette= schiller_type_colors)

# Rotate x-labels
plt.xticks(rotation=90)
plt.axvline(7, color="k", linestyle="--")

# %%
# Bar plot
# Count Plot (a.k.a. Bar Plot)
sns.countplot(x='style', data=df, palette= schiller_type_colors)

# Rotate x-labels
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
# Factor Plot
g = sns.factorplot(x='year',
                  y='nr_verb',
                  data=df,
                  hue='style', # Color by stage
                  col='style', # Separate by stage
                  kind='swarm') # Swarmplot

# rotate x-axis labels
g.set_xticklabels(rotation=-45)

# Doesn't work because only rotates last plot
# plt.xticks(rotation=-45)

# %% [markdown]
# <h2>Verteilung der Textlänge über die Zeit</h2>

# %% [markdown]
# Aus dem vorhandenen DataFrame wird nun ein neuer erzeugt, der lediglich die beiden Felder
# year und nr_token besitzt.

# %%
text_length = data[["year", "nr_token"]]

# %% [markdown]
# Ab jetzt wird es visuell! Die %-Anweisung wird benötigt, damit Jupyter die Plots direkt im Notebook anzeigen kann.
# Hier wird matplotlib zur Visualisierung benutzt, die numpy-Bibliothek für die numerische Datenverarbeitung
# wird später noch häufiger benötigt.
#
# Mehr zur Inline-Darstellung in Jupyter: https://ipython.readthedocs.io/en/stable/interactive/plotting.html
#
# Mehr zu matplotlib: https://matplotlib.org
#
# Mehr zu numpy: http://www.numpy.org
#
# Mehr zu set_index: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.set_index.html
#
# Mehr zu agg: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.core.groupby.DataFrameGroupBy.agg.html
#
# Mehr zu rename: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.rename.html

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np


data['year'] = pd.to_datetime(data['year_dt'], errors='coerce')


#data[["year", "nr_token"]].set_index("year").resample('M').agg({'nr_token': 'mean'}).rename(columns={'nr_token': '#tokens'}).plot()
data[["year", "nr_token"]].set_index("year").resample('M').agg({'nr_token': 'mean'}).rename(columns={'nr_token': '#tokens'}).plot()

# %%
data
# Out:
#                                                      name style  \
# number
# 0001                                            Demetrius     D
# 0002                          Der versöhnte Menschenfeind     D
# 0003                                Die Braut von Messina     D
# 0004                             Die Huldigung der Künste     L
# 0005                             Die Jungfrau von Orleans     D
# 0006                                           Die Räuber     D
# 0007                 Die Verschwörung des Fiesco zu Genua     D
# 0008                                           Don Carlos     D
# 0009                                     Kabale und Liebe     D
# 0010                                         Maria Stuart     D
# 0011                                               Semele     L
# 0012                                          Wallenstein     D
# 0013                                         Wilhelm Tell     D
# 0014                                            Der Abend     L
# 0015                                               Amalia     L
# 0016                                        an die Freude     L
# 0017                        das Geheimnis der Reminiszemz     L
# 0018                              das Ideal und das Leben     L
# 0019                       das verschleierte Bild zu Sais     L
# 0020                                         der Eroberer     L
# 0021                                     der Geisterseher     E
# 0022                                  der Neffe als Onkel     U
# 0023                                          der Parasit     U
# 0024                                      der Spaziergang
# 0025                                       der Venuswagen
# 0026                   der Verbrecher aus verlorener Ehre     E
# 0027                                    die deutsche Muse     L
# 0028                              die Entzückung an Laura     L
# 0029                die Götter Griechenlands ersteFassung     L
# 0030                                           die Ideale
# ...                                                   ...   ...
# 0064                                     Breite und Tiefe     L
# 0065                                             Columbus     L
# 0066                                  Das Eleusische Fest     L
# 0067              die Götter Griechenlands zweite Fassung     L
# 0068                                         das Geschenk     L
# 0069                                            das Glück     L
# 0070                                      der Alpenjaeger     L
# 0071                           Das Mädchen aus der Fremde     L
# 0072                              Das Mädchen von Orleans     L
# 0073                                       Das Siegesfest     L
# 0074                                 Das Spiel des Lebens     L
# 0075                                  Das weibliche Ideal     L
# 0076                                        Die Begegnung     L
# 0077                                   Des Mädchens Klage     L
# 0078                                     Zeus zu Herkules     L
# 0079                                Der Graf von Habsburg     L
# 0080                                Der Jüngling am Bache     L
# 0081                                      An den Frühling     L
# 0082                     An den Herausgeber der Propyläen     E
# 0083                                  an einen Moralisten     E
# 0084                                             An Minna
# 0085                           Das Glück und die Weisheit
# 0072        Das edle Bild der Menschheit zu verhöhnen,...        NaT
# 0073    Priams Feste war gesunken,        Troja lag in... 1802-01-01
# 0074        Wollt ihr in meinen Kasten sehn?        De...        NaT
# 0075    An Amanda Überall weichet das Weib dem Manne; ...        NaT
# 0076     Die Begegnung.     Noch seh' ich sie – umring... 1798-01-01
# 0077     Des Mädchens Klage.     Der Eichenwald brause... 1798-01-01
# 0078    Nicht aus meinem Nektar hast du dir Gottheit g...        NaT
# 0079    Zu Aachen in seiner Kaiserpracht,            I... 1803-01-01
# 0080    An der Quelle saß der Knabe,            Blumen... 1803-01-01
# 0081    Willkommen, schöner Jüngling!     Du Wonne der... 1782-01-01
# 0082    Ich komme von Betrachtung der Bilder zurück, d... 1799-01-01
# 0083     An einen Moralisten.  Was zürnst du unsrer fr...        NaT
# 0084    Träum' ich? ist mein Auge trüber?     Nebelt's...        NaT
# 0085    Entzweit mit einem Favoriten,     Flog einst F...        NaT
# 0086    In den Geschichtbüchern, welche die merkwürdig...        NaT
# 0087    Frisch athmet des Morgens lebendiger Hauch;   ...        NaT
# 0088    Nein, länger werd' ich diesen Kampf nicht kämp...        NaT
# 0089    Wollmar und Edwin waren Freunde und wohnten in...        NaT
# 0090          Selig durch die Liebe       Götter – dur...        NaT
# 0091     Die Blumen.  Kinder der verjüngten Sonne,    ...        NaT
# 0092    Freund! genügsam ist der Wesenlenker – Schämen...        NaT
# 0093    Lykurgus.  Um den Lykurgischen Plan gehörig wü...        NaT
#
#           year_dt  nr_token  nr_adj  nr_noun  nr_verb
# number
# 0001   1805-01-01       NaN     NaN      NaN      NaN
# 0002   1790-01-01       NaN     NaN      NaN      NaN
# 0003   1803-01-01       NaN     NaN      NaN      NaN
# 0004   1804-01-01       NaN     NaN      NaN      NaN
# 0005   1801-01-01       NaN     NaN      NaN      NaN
# 0006   1781-01-01       NaN     NaN      NaN      NaN
# 0007   1783-01-01       NaN     NaN      NaN      NaN
# 0008   1788-01-01       NaN     NaN      NaN      NaN
# 0009   1784-01-01       NaN     NaN      NaN      NaN
# 0010   1800-01-01       NaN     NaN      NaN      NaN
# 0011   1782-01-01       NaN     NaN      NaN      NaN
# 0012   1799-01-01       NaN     NaN      NaN      NaN
# 0013   1804-01-01       NaN     NaN      NaN      NaN
# 0014   1776-01-01       NaN     NaN      NaN      NaN
# 0015   1787-01-01       NaN     NaN      NaN      NaN
# 0016   1785-01-01       NaN     NaN      NaN      NaN
# 0017          NaT       NaN     NaN      NaN      NaN
# 0018   1795-01-01       NaN     NaN      NaN      NaN
# 0019   1795-01-01       NaN     NaN      NaN      NaN
# 0020          NaT       NaN     NaN      NaN      NaN
# 0021   1789-01-01       NaN     NaN      NaN      NaN
# 0022          NaT       NaN     NaN      NaN      NaN
# 0023          NaT       NaN     NaN      NaN      NaN
# 0024          NaT       NaN     NaN      NaN      NaN
# 0025          NaT       NaN     NaN      NaN      NaN
# 0026   1786-01-01       NaN     NaN      NaN      NaN
# 0027          NaT       NaN     NaN      NaN      NaN
# 0028          NaT       NaN     NaN      NaN      NaN
# 0029   1788-01-01       NaN     NaN      NaN      NaN
# 0030          NaT       NaN     NaN      NaN      NaN
# ...           ...       ...     ...      ...      ...
# 0064          NaT       NaN     NaN      NaN      NaN
# 0065          NaT       NaN     NaN      NaN      NaN
# 0066          NaT       NaN     NaN      NaN      NaN
# 0067   1800-01-01       NaN     NaN      NaN      NaN
# 0068          NaT       NaN     NaN      NaN      NaN
# 0069          NaT       NaN     NaN      NaN      NaN
# 0070   1804-01-01       NaN     NaN      NaN      NaN
# 0071          NaT       NaN     NaN      NaN      NaN
# 0072          NaT       NaN     NaN      NaN      NaN
# 0073   1802-01-01       NaN     NaN      NaN      NaN
# 0074          NaT       NaN     NaN      NaN      NaN
# 0075          NaT       NaN     NaN      NaN      NaN
# 0076   1798-01-01       NaN     NaN      NaN      NaN
# 0077   1798-01-01       NaN     NaN      NaN      NaN
# 0078          NaT       NaN     NaN      NaN      NaN
# 0079   1803-01-01       NaN     NaN      NaN      NaN
# 0080   1803-01-01       NaN     NaN      NaN      NaN
# 0081   1782-01-01       NaN     NaN      NaN      NaN
# 0082   1799-01-01       NaN     NaN      NaN      NaN
# 0083          NaT       NaN     NaN      NaN      NaN
# 0084          NaT       NaN     NaN      NaN      NaN
# 0085          NaT       NaN     NaN      NaN      NaN
# 0086          NaT       NaN     NaN      NaN      NaN
# 0087          NaT       NaN     NaN      NaN      NaN
# 0088          NaT       NaN     NaN      NaN      NaN
# 0089          NaT       NaN     NaN      NaN      NaN
# 0090          NaT       NaN     NaN      NaN      NaN
# 0091          NaT       NaN     NaN      NaN      NaN
# 0092          NaT       NaN     NaN      NaN      NaN
# 0093          NaT   11089.0  1003.0   2373.0   1855.0
#
# [93 rows x 9 columns]

# %% [markdown]
# <h2>Liste der längsten Artikel</h2>

# %% [markdown]
# Mehr zur Sortierung: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html
#
# Mehr zur Spaltenauswahl: https://pandas.pydata.org/pandas-docs/stable/indexing.html

# %%
data.sort_values(["nr_token"], ascending=False)[["name", "nr_token", "year"]].head(10)
# Out:
#                                            name  nr_token       year
# number
# 0093    Die Gesetzgebung des Lykurgus und Solon   11089.0        NaT
# 0001                                  Demetrius       NaN 1805-01-01
# 0002                Der versöhnte Menschenfeind       NaN 1790-01-01
# 0003                      Die Braut von Messina       NaN 1803-01-01
# 0004                   Die Huldigung der Künste       NaN 1804-01-01
# 0005                   Die Jungfrau von Orleans       NaN 1801-01-01
# 0006                                 Die Räuber       NaN 1781-01-01
# 0007       Die Verschwörung des Fiesco zu Genua       NaN 1783-01-01
# 0008                                 Don Carlos       NaN 1788-01-01
# 0009                           Kabale und Liebe       NaN 1784-01-01

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 0001 to 0093
# Data columns (total 9 columns):
# name        93 non-null object
# style       93 non-null object
# text        93 non-null object
# year        50 non-null datetime64[ns]
# year_dt     50 non-null datetime64[ns]
# nr_token    1 non-null float64
# nr_adj      1 non-null float64
# nr_noun     1 non-null float64
# nr_verb     1 non-null float64
# dtypes: datetime64[ns](2), float64(4), object(3)
# memory usage: 7.3+ KB
