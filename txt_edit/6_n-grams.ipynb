# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
#% matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
# load the data/ pickle
import pickle

# load it
with open('./data/output_df_wth_all_nr_all_perc_reading.pickle', 'rb') as handle:
    data = pickle.load(handle) 

df = data

# alles auf 2 Nachkommastellen beschränken
df.round(2)

# Spalte Text-Standart auf einen Integer Wert ändern (von " 6th and 7th grade"hin zu 7)
#df['text_standard'] = 

# flip Achsen zur besseren Übersicht.
df.T.round(2)
# Out:
# number                                                                     0001  \
# name                                                                  Demetrius
# style                                                                         D
# text                          Demetrius an der russischen Grenze   Er ist vo...
# year                                                                       1805
# year_dt                                                     1805-01-01 00:00:00
# nr_token                                                                   8486
# nr_adj                                                                      600
# nr_noun                                                                    1681
# nr_verb                                                                    1482
# per_verb                                                                17.4641
# per_noun                                                                19.8091
# per_adj                                                                 7.07047
# flesch_reading_ease                                                       72.46
# smog_index                                                                  8.9
# flesch_kincaid_grade                                                        7.1
# coleman_liau_index                                                        12.93
# automated_readability_index                                                11.2
# dale_chall_readability_score                                               7.14
# difficult_words                                                            1450
# linsear_write_formula                                                     4.875
# gunning_fog                                                               15.17
# text_standard                                                 6th and 7th grade
#
# number                                                                     0002  \
# name                                                Der versöhnte Menschenfeind
# style                                                                         D
# text                          Der versöhnte Menschenfeind - Fragment  Gegend...
# year                                                                       1790
# year_dt                                                     1790-01-01 00:00:00
# nr_token                                                                   7127
# nr_adj                                                                      584
# nr_noun                                                                    1328
# nr_verb                                                                    1286
# per_verb                                                                18.0441
# per_noun                                                                18.6334
# per_adj                                                                 8.19419
# flesch_reading_ease                                                       82.75
# smog_index                                                                  8.1
# flesch_kincaid_grade                                                        5.2
# coleman_liau_index                                                        12.23
# automated_readability_index                                                 9.9
# dale_chall_readability_score                                               6.92
# difficult_words                                                            1193
# linsear_write_formula                                                   3.63636
# gunning_fog                                                             14.1384
# text_standard                                                 3th and 4th grade
#
# number                                                                     0003  \
# name                                                      Die Braut von Messina
# style                                                                         D
# text                          Die Braut von Messina oder die feindlichen Brü...
# year                                                                       1803
# year_dt                                                     1803-01-01 00:00:00
# nr_token                                                                  27129
# nr_adj                                                                     2348
# nr_noun                                                                    5122
# nr_verb                                                                    3624
# per_verb                                                                13.3584
# per_noun                                                                18.8802
# per_adj                                                                 8.65494
# flesch_reading_ease                                                       14.15
# smog_index                                                                  8.2
# flesch_kincaid_grade                                                         15
# coleman_liau_index                                                        12.46
# automated_readability_index                                                10.6
# dale_chall_readability_score                                               6.63
# difficult_words                                                            3508
# linsear_write_formula                                                   7.91667
# gunning_fog                                                             13.6466
# text_standard                                                 7th and 8th grade
#
# number                                                                     0004  \
# name                                                   Die Huldigung der Künste
# style                                                                         D
# text                          Ihrer Kaiserl. Hoheit       der Frau Erbprinze...
# year                                                                       1804
# year_dt                                                     1804-01-01 00:00:00
# nr_token                                                                   1985
# nr_adj                                                                      157
# nr_noun                                                                     452
# nr_verb                                                                     242
# per_verb                                                                12.1914
# per_noun                                                                22.7708
# per_adj                                                                 7.90932
# flesch_reading_ease                                                       22.51
# smog_index                                                                  7.4
# flesch_kincaid_grade                                                       13.8
# coleman_liau_index                                                        11.82
# automated_readability_index                                                10.1
# dale_chall_readability_score                                               7.35
# difficult_words                                                             333
# linsear_write_formula                                                   6.42857
# gunning_fog                                                             15.4897
# text_standard                                                 6th and 7th grade
#
# number                                                                     0005  \
# name                                                   Die Jungfrau von Orleans
# style                                                                         D
# text                          Die Jungfrau von Orleans Eine romantische Trag...
# year                                                                       1801
# year_dt                                                     1801-01-01 00:00:00
# nr_token                                                                  32189
# nr_adj                                                                     2308
# nr_noun                                                                    6195
# nr_verb                                                                    4801
# per_verb                                                                 14.915
# per_noun                                                                19.2457
# per_adj                                                                 7.17015
# flesch_reading_ease                                                       16.08
# smog_index                                                                  7.6
# flesch_kincaid_grade                                                       14.2
# coleman_liau_index                                                        11.59
# automated_readability_index                                                 9.2
# dale_chall_readability_score                                               6.31
# difficult_words                                                            3747
# linsear_write_formula                                                      53.5
# gunning_fog                                                             12.3116
# text_standard                                               11th and 12th grade
#
# number                                                                     0006  \
# name                                                                 Die Räuber
# style                                                                         D
# text                          Die Räuber Ein Schauspiel        Quae medicame...
# year                                                                       1781
# year_dt                                                     1781-01-01 00:00:00
# nr_token                                                                  42202
# nr_adj                                                                     3047
# nr_noun                                                                    7807
# nr_verb                                                                    7432
# per_verb                                                                17.6105
# per_noun                                                                18.4991
# per_adj                                                                 7.22004
# flesch_reading_ease                                                       84.07
# smog_index                                                                  7.3
# flesch_kincaid_grade                                                        4.7
# coleman_liau_index                                                        11.01
# automated_readability_index                                                 8.6
# dale_chall_readability_score                                               6.23
# difficult_words                                                            5317
# linsear_write_formula                                                   2.60714
# gunning_fog                                                             12.0275
# text_standard                                                 2th and 3th grade
#
# number                                                                     0007  \
# name                                       Die Verschwörung des Fiesco zu Genua
# style                                                                         D
# text                          Die Verschwörung des Fiesco zu Genua Ein repub...
# year                                                                       1783
# year_dt                                                     1783-01-01 00:00:00
# nr_token                                                                  30978
# nr_adj                                                                     2404
# nr_noun                                                                    6242
# nr_verb                                                                    5382
# per_verb                                                                17.3736
# per_noun                                                                20.1498
# per_adj                                                                 7.76035
# flesch_reading_ease                                                       78.85
# smog_index                                                                  7.5
# flesch_kincaid_grade                                                        4.6
# coleman_liau_index                                                        12.44
# automated_readability_index                                                 8.9
# dale_chall_readability_score                                               6.35
# difficult_words                                                            4438
# linsear_write_formula                                                      11.2
# gunning_fog                                                             11.4539
# text_standard                                               11th and 12th grade
#
# number                                                                     0008  \
# name                                                                 Don Carlos
# style                                                                         D
# text                           Don Carlos, Infant von Spanien Ein dramatisch...
# year                                                                       1788
# year_dt                                                     1788-01-01 00:00:00
# nr_token                                                                  45823
# nr_adj                                                                     2795
# nr_noun                                                                    7636
# nr_verb                                                                    6911
# per_verb                                                                15.0819
# per_noun                                                                16.6641
# per_adj                                                                 6.09956
# flesch_reading_ease                                                       10.16
# smog_index                                                                  6.7
# flesch_kincaid_grade                                                       14.4
# coleman_liau_index                                                        10.65
# automated_readability_index                                                 7.6
# dale_chall_readability_score                                               5.97
# difficult_words                                                            4794
# linsear_write_formula                                                   2.03125
# gunning_fog                                                              10.761
# text_standard                                               10th and 11th grade
#
# number                                                                     0009  \
# name                                                           Kabale und Liebe
# style                                                                         D
# text                           Kabale und Liebe Ein bürgerliches Trauerspiel...
# year                                                                       1784
# year_dt                                                     1784-01-01 00:00:00
# nr_token                                                                  31778
# nr_adj                                                                     2347
# nr_noun                                                                    6126
# nr_verb                                                                    5484
# per_verb                                                                17.2572
# per_noun                                                                19.2775
# per_adj                                                                 7.38561
# flesch_reading_ease                                                       85.18
# smog_index                                                                  7.5
# flesch_kincaid_grade                                                        4.2
# coleman_liau_index                                                        10.88
# automated_readability_index                                                 8.1
# dale_chall_readability_score                                               6.15
# difficult_words                                                            4004
# linsear_write_formula                                                   2.85714
# gunning_fog                                                             11.5219
# text_standard                                                 7th and 8th grade
#
# number                                                                     0010  \
# name                                                               Maria Stuart
# style                                                                         D
# text                          Maria Stuart Trauerspiel in fünf Aufzügen  Eli...
# year                                                                       1800
# year_dt                                                     1800-01-01 00:00:00
# nr_token                                                                  34801
# nr_adj                                                                     2258
# nr_noun                                                                    6491
# nr_verb                                                                    5173
# per_verb                                                                14.8645
# per_noun                                                                18.6518
# per_adj                                                                 6.48832
# flesch_reading_ease                                                       -0.54
# smog_index                                                                  7.5
# flesch_kincaid_grade                                                       16.5
# coleman_liau_index                                                        12.22
# automated_readability_index                                                 9.5
# dale_chall_readability_score                                               6.41
# difficult_words                                                            4246
# linsear_write_formula                                                     24.25
# gunning_fog                                                             12.4927
# text_standard                                               12th and 13th grade
#
# number                                              ...                          \
# name                                                ...
# style                                               ...
# text                                                ...
# year                                                ...
# year_dt                                             ...
# nr_token                                            ...
# nr_adj                                              ...
# nr_noun                                             ...
# nr_verb                                             ...
# per_verb                                            ...
# per_noun                                            ...
# per_adj                                             ...
# flesch_reading_ease                                 ...
# smog_index                                          ...
# flesch_kincaid_grade                                ...
# coleman_liau_index                                  ...
# automated_readability_index                         ...
# dale_chall_readability_score                        ...
# difficult_words                                     ...
# linsear_write_formula                               ...
# gunning_fog                                         ...
# text_standard                                       ...
#
# number                                                                     0654  \
# name                                                              an G Goeschen
# style                                                                         B
# text                          [Weimar 25. Febr. (?) Freitag. 1805.]  Hier üb...
# year                                                                       1805
# year_dt                                                     1805-01-01 00:00:00
# nr_token                                                                    870
# nr_adj                                                                       57
# nr_noun                                                                     153
# nr_verb                                                                     115
# per_verb                                                                13.2184
# per_noun                                                                17.5862
# per_adj                                                                 6.55172
# flesch_reading_ease                                                       88.97
# smog_index                                                                    8
# flesch_kincaid_grade                                                        4.8
# coleman_liau_index                                                        11.25
# automated_readability_index                                                  10
# dale_chall_readability_score                                               7.36
# difficult_words                                                             146
# linsear_write_formula                                                      7.25
# gunning_fog                                                             15.8606
# text_standard                                                 7th and 8th grade
#
# number                                                                     0655  \
# name                                                               an A Iffland
# style                                                                         B
# text                          Weimar, 5. Januar [Mittwoch] 1805. Ich lebe au...
# year                                                                       1805
# year_dt                                                     1805-01-01 00:00:00
# nr_token                                                                    815
# nr_adj                                                                       79
# nr_noun                                                                     135
# nr_verb                                                                     125
# per_verb                                                                15.3374
# per_noun                                                                16.5644
# per_adj                                                                 9.69325
# flesch_reading_ease                                                       81.73
# smog_index                                                                  8.6
# flesch_kincaid_grade                                                        5.6
# coleman_liau_index                                                           12
# automated_readability_index                                                10.3
# dale_chall_readability_score                                               7.55
# difficult_words                                                             156
# linsear_write_formula                                                         7
# gunning_fog                                                             16.0116
# text_standard                                                 5th and 6th grade
#
# number                                                                     0656  \
# name                                                              an F Frommann
# style                                                                         B
# text                          Weimar 3. April [Sonntag] 1805. Der Druck ist ...
# year                                                                       1805
# year_dt                                                     1805-01-01 00:00:00
# nr_token                                                                    279
# nr_adj                                                                       28
# nr_noun                                                                      56
# nr_verb                                                                      36
# per_verb                                                                12.9032
# per_noun                                                                20.0717
# per_adj                                                                 10.0358
# flesch_reading_ease                                                       74.49
# smog_index                                                                  7.5
# flesch_kincaid_grade                                                        6.3
# coleman_liau_index                                                        12.35
# automated_readability_index                                                  10
# dale_chall_readability_score                                               8.25
# difficult_words                                                              65
# linsear_write_formula                                                      10.8
# gunning_fog                                                             17.4417
# text_standard                                                 7th and 8th grade
#
# number                                                                     0657  \
# name                                                                an H Paulus
# style                                                                         B
# text                          Weimar, 2. April [Sonnabend] 1805. Glauben Sie...
# year                                                                       1805
# year_dt                                                     1805-01-01 00:00:00
# nr_token                                                                    263
# nr_adj                                                                       23
# nr_noun                                                                      39
# nr_verb                                                                      39
# per_verb                                                                14.8289
# per_noun                                                                14.8289
# per_adj                                                                 8.74525
# flesch_reading_ease                                                       84.27
# smog_index                                                                  8.5
# flesch_kincaid_grade                                                        4.6
# coleman_liau_index                                                        11.99
# automated_readability_index                                                 9.3
# dale_chall_readability_score                                               7.56
# difficult_words                                                              52
# linsear_write_formula                                                     5.125
# gunning_fog                                                             15.3471
# text_standard                                                 8th and 9th grade
#
# number                                                                     0658  \
# name                                                            an F Niethammer
# style                                                                         B
# text                          Weimar 2. April [Sonnabend] 1805. Mein langes ...
# year                                                                       1805
# year_dt                                                     1805-01-01 00:00:00
# nr_token                                                                    411
# nr_adj                                                                       31
# nr_noun                                                                      67
# nr_verb                                                                      64
# per_verb                                                                15.5718
# per_noun                                                                16.3017
# per_adj                                                                 7.54258
# flesch_reading_ease                                                       73.47
# smog_index                                                                  8.1
# flesch_kincaid_grade                                                        6.7
# coleman_liau_index                                                        12.58
# automated_readability_index                                                10.7
# dale_chall_readability_score                                               7.87
# difficult_words                                                              85
# linsear_write_formula                                                         6
# gunning_fog                                                             16.7573
# text_standard                                                 7th and 8th grade
#
# number                                                                     0659  \
# name                                                                an L Frankh
# style                                                                         B
# text                          Weimar 27. März [Sonntag] 1805. Ja, wohl ist e...
# year                                                                       1805
# year_dt                                                     1805-01-01 00:00:00
# nr_token                                                                    484
# nr_adj                                                                       42
# nr_noun                                                                      89
# nr_verb                                                                      77
# per_verb                                                                15.9091
# per_noun                                                                18.3884
# per_adj                                                                 8.67769
# flesch_reading_ease                                                       77.06
# smog_index                                                                  8.8
# flesch_kincaid_grade                                                        7.4
# coleman_liau_index                                                        13.17
# automated_readability_index                                                13.1
# dale_chall_readability_score                                               8.07
# difficult_words                                                             103
# linsear_write_formula                                                      10.5
# gunning_fog                                                             18.5846
# text_standard                                                 8th and 9th grade
#
# number                                                                     0660  \
# name                                                                 an F Cotta
# style                                                                         B
# text                          Weimar, 6. Januar [Donnerstag] 1805. Hubers To...
# year                                                                       1805
# year_dt                                                     1805-01-01 00:00:00
# nr_token                                                                   2333
# nr_adj                                                                      234
# nr_noun                                                                     426
# nr_verb                                                                     351
# per_verb                                                                 15.045
# per_noun                                                                18.2598
# per_adj                                                                   10.03
# flesch_reading_ease                                                       71.85
# smog_index                                                                  8.9
# flesch_kincaid_grade                                                        7.3
# coleman_liau_index                                                        12.06
# automated_readability_index                                                10.8
# dale_chall_readability_score                                               7.05
# difficult_words                                                             368
# linsear_write_formula                                                      7.25
# gunning_fog                                                             15.1239
# text_standard                                                 6th and 7th grade
#
# number                                                                     0661  \
# name                                                                 an F Stein
# style                                                                         B
# text                          Weimar 13. April [Mittwoch] 1805. Der Schauspi...
# year                                                                       1805
# year_dt                                                     1805-01-01 00:00:00
# nr_token                                                                    355
# nr_adj                                                                       26
# nr_noun                                                                      55
# nr_verb                                                                      58
# per_verb                                                                 16.338
# per_noun                                                                 15.493
# per_adj                                                                 7.32394
# flesch_reading_ease                                                       77.57
# smog_index                                                                  7.6
# flesch_kincaid_grade                                                        7.2
# coleman_liau_index                                                        12.59
# automated_readability_index                                                12.3
# dale_chall_readability_score                                                  8
# difficult_words                                                              74
# linsear_write_formula                                                       8.8
# gunning_fog                                                              18.255
# text_standard                                                 7th and 8th grade
#
# number                                                                     0662  \
# name                                                                an W Goethe
# style                                                                         B
# text                          14. Januar [Freitag] 1805.  Es thut mir recht ...
# year                                                                       1805
# year_dt                                                     1805-01-01 00:00:00
# nr_token                                                                   2520
# nr_adj                                                                      211
# nr_noun                                                                     414
# nr_verb                                                                     409
# per_verb                                                                16.2302
# per_noun                                                                16.4286
# per_adj                                                                 8.37302
# flesch_reading_ease                                                       69.72
# smog_index                                                                  9.5
# flesch_kincaid_grade                                                        8.1
# coleman_liau_index                                                         13.4
# automated_readability_index                                                12.7
# dale_chall_readability_score                                               7.41
# difficult_words                                                             430
# linsear_write_formula                                                   6.28571
# gunning_fog                                                             16.6174
# text_standard                                               12th and 13th grade
#
# number                                                                     0663
# name                                                               an G Koerner
# style                                                                         B
# text                          Weimar 20. Jan. [Donnerstag] 1805. So wie das ...
# year                                                                       1805
# year_dt                                                     1805-01-01 00:00:00
# nr_token                                                                   1589
# nr_adj                                                                      138
# nr_noun                                                                     245
# nr_verb                                                                     269
# per_verb                                                                16.9289
# per_noun                                                                15.4185
# per_adj                                                                 8.68471
# flesch_reading_ease                                                        79.6
# smog_index                                                                  8.7
# flesch_kincaid_grade                                                        6.4
# coleman_liau_index                                                        11.95
# automated_readability_index                                                  11
# dale_chall_readability_score                                               7.53
# difficult_words                                                             296
# linsear_write_formula                                                       8.6
# gunning_fog                                                             16.5335
# text_standard                                                 8th and 9th grade
#
# [22 rows x 663 columns]
